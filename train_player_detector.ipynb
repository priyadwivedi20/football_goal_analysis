# %% [markdown]
# <a href="https://colab.research.google.com/github/priyadwivedi20/football_goal_analysis/blob/main/train_player_detector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Tue Nov 12 18:09:29 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   58C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !pip install -q ultralytics roboflow
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.8/883.8 kB 47.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 7.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.4 MB/s eta 0:00:00

# %%
from roboflow import Roboflow
from google.colab import userdata
from IPython.display import Image

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

ROBOFLOW_API_KEY = userdata.get('ROBOFLOW_API_KEY')
rf = Roboflow(api_key=ROBOFLOW_API_KEY)

project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(10)
dataset = version.download("yolov8")
# Out:
# mkdir: cannot create directory ‘/content/datasets’: File exists
# /content/datasets
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to football-players-detection-10 in yolov8:: 100%|██████████| 636/636 [00:00<00:00, 2427.69it/s]
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !sed -i 's|\(train: \).*|\1../train/images|' {dataset.location}/data.yaml
# !sed -i 's|\(val: \).*|\1../valid/images|' {dataset.location}/data.yaml

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8x.pt data={dataset.location}/data.yaml batch=4 epochs=50 imgsz=1280 plots=True
# Out:
# /content
# Ultralytics 8.3.29 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo detect predict model='runs/detect/train2/weights/best.pt' source='input.mp4'
# Out:
# Ultralytics 8.3.29 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68,127,420 parameters, 0 gradients, 257.4 GFLOPs
#
# video 1/1 (frame 1/898) /content/input.mp4: 736x1280 21 players, 1 referee, 118.7ms
# video 1/1 (frame 2/898) /content/input.mp4: 736x1280 19 players, 2 referees, 118.0ms
# video 1/1 (frame 3/898) /content/input.mp4: 736x1280 20 players, 2 referees, 118.1ms
# video 1/1 (frame 4/898) /content/input.mp4: 736x1280 21 players, 1 referee, 117.5ms
# video 1/1 (frame 5/898) /content/input.mp4: 736x1280 21 players, 1 referee, 117.5ms
# video 1/1 (frame 6/898) /content/input.mp4: 736x1280 1 goalkeeper, 20 players, 1 referee, 118.6ms
# video 1/1 (frame 7/898) /content/input.mp4: 736x1280 20 players, 1 referee, 118.6ms
# video 1/1 (frame 8/898) /content/input.mp4: 736x1280 20 players, 1 referee, 118.8ms
# video 1/1 (frame 9/898) /content/input.mp4: 736x1280 19 players, 1 referee, 117.4ms
# ...
